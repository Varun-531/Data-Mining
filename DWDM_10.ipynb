# %% [markdown]
# <a href="https://colab.research.google.com/github/Varun-531/Data-Mining/blob/main/DWDM_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
data = pd.DataFrame(iris.data,columns = iris.feature_names)
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
X = data[['sepal length (cm)','sepal width (cm)']]
dbscan = DBSCAN(eps = 0.5,min_samples = 5)
dbscan.fit(X)
labels = dbscan.labels_
plt.scatter(X['sepal length (cm)'],X['sepal width (cm)'],c=labels)
plt.xlabel('sepal Length')
plt.ylabel('sepal Width')
plt.show()
