# %% [markdown]
# <a href="https://colab.research.google.com/github/Varun-531/Data-Mining/blob/main/DWDM_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/students_placement_data.csv')
data
# Out:
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A            87.3                     65.30
# 1          2      F       A            89.0                     92.40
# 2          3      F       A            67.0                     68.00
# 3          4      M       A            71.0                     70.40
# 4          5      M       A             NaN                     65.50
# ..       ...    ...     ...             ...                       ...
# 112      113      M       B            81.1                     78.60
# 113      114      M       B            81.3                     85.12
# 114      115      M       B            83.5                     89.90
# 115      116      M       B            85.5                     90.63
# 116      117      M       B            80.0                     83.33
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# ...

# %%
missingValues = data.isnull().sum()
print(missingValues)
# Out:
# Roll No                               0
# Gender                                0
# Section                               0
# SSC Percentage                        1
# inter_Diploma_percentage              0
# B.Tech_percentage                     0
# Backlogs                              0
# registered_for_ Placement_Training    1
# placement status                      0
# dtype: int64

# %%
data = data.dropna()
data
# Out:
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A           87.30                     65.30
# 1          2      F       A           89.00                     92.40
# 2          3      F       A           67.00                     68.00
# 3          4      M       A           71.00                     70.40
# 5          6      M       A           81.26                     68.00
# ..       ...    ...     ...             ...                       ...
# 112      113      M       B           81.10                     78.60
# 113      114      M       B           81.30                     85.12
# 114      115      M       B           83.50                     89.90
# 115      116      M       B           85.50                     90.63
# 116      117      M       B           80.00                     83.33
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# ...

# %%
missingValues = data.isnull().sum()
print(missingValues)
# Out:
# Roll No                               0
# Gender                                0
# Section                               0
# SSC Percentage                        0
# inter_Diploma_percentage              0
# B.Tech_percentage                     0
# Backlogs                              0
# registered_for_ Placement_Training    0
# placement status                      0
# dtype: int64

# %%
X = data.drop('Gender',axis=1)
X = X.drop('Section',axis=1)
X = X.drop('registered_for_ Placement_Training',axis=1)
X = X.drop('Roll No',axis=1)
X
# Out:
#      SSC Percentage  inter_Diploma_percentage  B.Tech_percentage  Backlogs  \
# 0             87.30                     65.30              40.00        18
# 1             89.00                     92.40              71.45         0
# 2             67.00                     68.00              45.26        13
# 3             71.00                     70.40              36.47        17
# 5             81.26                     68.00              62.20         6
# ..              ...                       ...                ...       ...
# 112           81.10                     78.60              35.84        16
# 113           81.30                     85.12              68.50         0
# 114           83.50                     89.90              76.30         0
# 115           85.50                     90.63              74.50         0
# 116           80.00                     83.33              65.53         0
#
#     placement status
# 0         Not placed
# 1             Placed
# ...

# %%
data['Roll No'], data['Backlogs']
# Out:
# (0        1
#  1        2
#  2        3
#  3        4
#  5        6
#        ...
#  112    113
#  113    114
#  114    115
#  115    116
#  116    117
#  Name: Roll No, Length: 115, dtype: int64,
#  0      18
#  1       0
#  2      13
#  3      17
#  5       6
#         ..
#  112    16
#  113     0
#  114     0
#  115     0
#  116     0
#  Name: Backlogs, Length: 115, dtype: int64)

# %% [markdown]
# # **categorial data**

# %%
data['no of backlogs'] = pd.cut(data['Backlogs'],bins=[-1,10,20,np.inf],labels=["0-10","10-20",">20"])
data.head(4)
# Out:
# <ipython-input-240-a4665e693412>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['no of backlogs'] = pd.cut(data['Backlogs'],bins=[-1,10,20,np.inf],labels=["0-10","10-20",">20"])
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      68.0
# 3        4      M       A            71.0                      70.4
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# ...

# %%
data['Rating'] = pd.cut(data['Backlogs'],bins=[-1,10,20,np.inf],labels = ["Good","Average","Worst"])
data
# Out:
# <ipython-input-241-e077d6bedc8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rating'] = pd.cut(data['Backlogs'],bins=[-1,10,20,np.inf],labels = ["Good","Average","Worst"])
#      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A           87.30                     65.30
# 1          2      F       A           89.00                     92.40
# 2          3      F       A           67.00                     68.00
# 3          4      M       A           71.00                     70.40
# 5          6      M       A           81.26                     68.00
# ..       ...    ...     ...             ...                       ...
# ...

# %% [markdown]
# # **Scaling data**

# %%
X = X.drop('placement status',axis =1 )
Y = data['placement status']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_scaled,Y,test_size=0.2)
